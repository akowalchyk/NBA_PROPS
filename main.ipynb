# %%
import importlib

import utils
importlib.reload(utils)
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import time
from datetime import datetime
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv("player_data_final.csv")
df['Tm'] = pd.factorize(df['Tm'])[0]
df['Opp'] = pd.factorize(df['Opp'])[0]
df['player_url'] = pd.factorize(df['player_url'])[0]
df['pos'] = pd.factorize(df['pos'])[0]
df['day'] = pd.factorize(df['day'])[0]
df.to_csv("fatorized.csv", index=False)
print(df.sample)
sb.set(rc = {'figure.figsize':(30,30)})
pt = sb.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# <bound method NDFrame.sample of       Tm  away  Opp   PTS  player_url  pos  day    last_MP  \
# 0      0     0    0  10.0           0    0    0        NaN
# 1      0     1    1   4.0           0    0    1  1076000.0
# 2      0     1    2  18.0           0    0    2  1049000.0
# 3      0     1    2  10.0           0    0    3  2012000.0
# 4      0     0    3   7.0           0    0    0  2023000.0
# ...   ..   ...  ...   ...         ...  ...  ...        ...
# 1939  17     1   24   4.0          30    0    0   770000.0
# 1940  17     1    6  16.0          30    0    6   861000.0
# 1941  17     1   26   6.0          30    0    2  1156000.0
# 1942  17     1   26   7.0          30    0    5   891000.0
# 1943  17     0   10   6.0          30    0    6  1286000.0
#
#       last_3_game_MP_avg  last_2_game_MP_diff  ...  last_2_game_GmSc_diff  \
# 0                    NaN                  NaN  ...                    NaN
# 1                    NaN                  NaN  ...                    NaN
# ...
